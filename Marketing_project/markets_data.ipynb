# %%
# %time
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import warnings
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %time
warnings.filterwarnings('ignore')
# Load configuration from JSON file
with open('conf.json', 'r') as config_file:
    config = json.load(config_file)

# Fetching credentials from the configuration
server = config['server']
database = config['database']
username = config['username']
password = config['password']
driver = config['driver']

# Create a database connection string
connection_string = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver={driver}&TrustServerCertificate=yes"

# Create a SQLAlchemy engine
engine = create_engine(connection_string)

# Example query
query = 'SELECT * FROM [Testing].[dbo].[marketing_data]'

# Execute the query and load data into a pandas DataFrame
df = pd.read_sql(query, engine)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Afficher les premières lignes de la dataframe
df.info()
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   bool
#  21  AcceptedCmp4         2240 non-null   bool
#  22  AcceptedCmp5         2240 non-null   bool
#  23  AcceptedCmp1         2240 non-null   bool
#  24  AcceptedCmp2         2240 non-null   bool
#  25  Response             2240 non-null   bool
#  26  Complain             2240 non-null   bool
#  27  Country              2240 non-null   object
# dtypes: bool(7), float64(1), int64(16), object(4)
# memory usage: 382.9+ KB
#    ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   0        1985  Graduation        Married  70951.0        0         0
# 1   1        1961  Graduation         Single  57091.0        0         0
# 2   9        1975      Master         Single  46098.0        1         1
# 3  13        1947         PhD          Widow  25358.0        0         1
# 4  17        1971         PhD        Married  60491.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  NumStorePurchases  NumWebVisitsMonth  \
# 0  2013-05-04       66       239  ...                  9                  1
# 1  2014-06-15        0       464  ...                  7                  5
# 2  2012-08-18       86        57  ...                  2                  8
# 3  2013-07-22       57        19  ...                  3                  6
# 4  2013-09-06       81       637  ...                  7                  5
#
#    AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# 0         False         False         False         False         False
# 1         False         False         False         False          True
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    Response  Complain  Country
# 0     False     False       SA
# 1      True     False       CA
# 2     False     False       CA
# 3     False     False       SA
# 4     False     False       SP
#
# [5 rows x 28 columns]

# %% [markdown]
# Transformer la colonne "Dt_customer" au format datetime

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])
df['Dt_Customer'].info
# Out:
# <bound method Series.info of 0      2013-05-04
# 1      2014-06-15
# 2      2012-08-18
# 3      2013-07-22
# 4      2013-09-06
#           ...
# 2235   2014-03-23
# 2236   2013-08-29
# 2237   2013-05-20
# 2238   2014-02-25
# 2239   2013-12-07
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]>

# %%
df.describe().reset_index().T
# Out:
#                           0                              1  \
# index                 count                           mean
# ID                   2240.0                    5592.159821
# Year_Birth           2240.0                    1968.805804
# Income               2216.0                   52247.251354
# Kidhome              2240.0                       0.444196
# Teenhome             2240.0                        0.50625
# Dt_Customer            2240  2013-07-10 10:01:42.857142784
# Recency              2240.0                      49.109375
# MntWines             2240.0                     303.935714
# MntFruits            2240.0                      26.302232
# MntMeatProducts      2240.0                         166.95
# MntFishProducts      2240.0                      37.525446
# MntSweetProducts     2240.0                      27.062946
# MntGoldProds         2240.0                      44.021875
# NumDealsPurchases    2240.0                          2.325
# NumWebPurchases      2240.0                       4.084821
# NumCatalogPurchases  2240.0                       2.662054
# NumStorePurchases    2240.0                       5.790179
# NumWebVisitsMonth    2240.0                       5.316518
#
#                                        2                    3  \
# index                                min                  25%
# ID                                   0.0              2828.25
# Year_Birth                        1893.0               1959.0
# Income                            1730.0              35303.0
# Kidhome                              0.0                  0.0
# Teenhome                             0.0                  0.0
# Dt_Customer          2012-07-30 00:00:00  2013-01-16 00:00:00
# Recency                              0.0                 24.0
# MntWines                             0.0                23.75
# MntFruits                            0.0                  1.0
# MntMeatProducts                      0.0                 16.0
# MntFishProducts                      0.0                  3.0
# MntSweetProducts                     0.0                  1.0
# MntGoldProds                         0.0                  9.0
# NumDealsPurchases                    0.0                  1.0
# NumWebPurchases                      0.0                  2.0
# NumCatalogPurchases                  0.0                  0.0
# NumStorePurchases                    0.0                  3.0
# NumWebVisitsMonth                    0.0                  3.0
#
#                                        4                    5  \
# index                                50%                  75%
# ID                                5458.5              8427.75
# Year_Birth                        1970.0               1977.0
# Income                           51381.5              68522.0
# Kidhome                              0.0                  1.0
# Teenhome                             0.0                  1.0
# Dt_Customer          2013-07-08 12:00:00  2013-12-30 06:00:00
# Recency                             49.0                 74.0
# MntWines                           173.5               504.25
# MntFruits                            8.0                 33.0
# MntMeatProducts                     67.0                232.0
# MntFishProducts                     12.0                 50.0
# MntSweetProducts                     8.0                 33.0
# MntGoldProds                        24.0                 56.0
# NumDealsPurchases                    2.0                  3.0
# NumWebPurchases                      4.0                  6.0
# NumCatalogPurchases                  2.0                  4.0
# NumStorePurchases                    5.0                  8.0
# NumWebVisitsMonth                    6.0                  7.0
#
#                                        6             7
# index                                max           std
# ID                               11191.0   3246.662198
# Year_Birth                        1996.0     11.984069
# Income                          666666.0  25173.076661
# Kidhome                              2.0      0.538398
# Teenhome                             2.0      0.544538
# Dt_Customer          2014-06-29 00:00:00           NaN
# Recency                             99.0     28.962453
# MntWines                          1493.0    336.597393
# MntFruits                          199.0     39.773434
# MntMeatProducts                   1725.0    225.715373
# MntFishProducts                    259.0     54.628979
# MntSweetProducts                   263.0     41.280498
# MntGoldProds                       362.0     52.167439
# NumDealsPurchases                   15.0      1.932238
# NumWebPurchases                     27.0      2.778714
# NumCatalogPurchases                 28.0      2.923101
# NumStorePurchases                   13.0      3.250958
# NumWebVisitsMonth                   20.0      2.426645

# %% [markdown]
# Investigation des valeurs nulles

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Income                 24
# ID                      0
# NumDealsPurchases       0
# Complain                0
# Response                0
# AcceptedCmp2            0
# AcceptedCmp1            0
# AcceptedCmp5            0
# AcceptedCmp4            0
# AcceptedCmp3            0
# NumWebVisitsMonth       0
# NumStorePurchases       0
# NumCatalogPurchases     0
# NumWebPurchases         0
# MntGoldProds            0
# Year_Birth              0
# MntSweetProducts        0
# MntFishProducts         0
# MntMeatProducts         0
# MntFruits               0
# MntWines                0
# Recency                 0
# Dt_Customer             0
# Teenhome                0
# Kidhome                 0
# Marital_Status          0
# Education               0
# Country                 0
# dtype: int64

# %% [markdown]
# Traitement sur les colonnes

# %%
# Remplacer les espaces dans les noms des colonnes
df.columns = df.columns.str.replace(' ', '')

# Assurer que la colonne 'Income' est de type string avant de remplacer le $ et les espaces dans toutes les lignes
df['Income'] = df['Income'].astype(str).str.replace('$', '', regex=False)

# Remplacer les virgules et convertir en float dans la colonne 'Income'
df['Income'] = df['Income'].str.replace(',', '', regex=False).astype(float)

df.head()
# Out:
#    ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   0        1985  Graduation        Married  70951.0        0         0
# 1   1        1961  Graduation         Single  57091.0        0         0
# 2   9        1975      Master         Single  46098.0        1         1
# 3  13        1947         PhD          Widow  25358.0        0         1
# 4  17        1971         PhD        Married  60491.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  NumStorePurchases  NumWebVisitsMonth  \
# 0  2013-05-04       66       239  ...                  9                  1
# 1  2014-06-15        0       464  ...                  7                  5
# 2  2012-08-18       86        57  ...                  2                  8
# 3  2013-07-22       57        19  ...                  3                  6
# 4  2013-09-06       81       637  ...                  7                  5
#
#    AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# 0         False         False         False         False         False
# 1         False         False         False         False          True
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    Response  Complain  Country
# 0     False     False       SA
# 1      True     False       CA
# 2     False     False       CA
# 3     False     False       SA
# 4     False     False       SP
#
# [5 rows x 28 columns]

# %% [markdown]
# Visualizer la dispersion des données de la colonne 'Income' pour se décider de la manière d'imputation des valeurs

# %%
plt.figure(figsize =(6,4))
sns.histplot(df['Income'], kde=False)
plt.title('Visualisation de la distribution de la colonne "Income"',size=20)
plt.xlabel('Income')
plt.ylabel  ('Count')
plt.grid()

# %%
df['Income'].plot(kind='box',figsize=(3,4), patch_artist=True)
# Out:
# <Axes: >

# %% [markdown]
# Remplacer les valeurs nulles par la médiane

# %%
df['Income']=df['Income'].fillna(df['Income'].median)
df['Income'] = pd.to_numeric(df['Income'], errors='coerce')

# %% [markdown]
# Box plots de quelques colonnes

# %%
df_to_plot=df.drop(columns=['ID', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain']).select_dtypes(include=np.number)

df_to_plot.plot(kind='box',subplots=True, figsize=(12,13), layout=(4,4), patch_artist=True, grid=True)
plt.subplots_adjust(wspace=0.4)

# %% [markdown]
# Suppression les dates de naissances <1900 étant donné que potentiellement ce sont des erreurs de saisie et visualisation du filtrage

# %%
df=df[df['Year_Birth']> 1900].reset_index(drop=True)
plt.figure(figsize=(3,4))
df['Year_Birth'].plot(kind='box', grid=True, patch_artist=True)
# Out:
# <Axes: >

# %% [markdown]
# Ingénieurie des colonnes

# %%
# Dependents
df['Enfants'] = df['Kidhome'] + df['Teenhome']

# Année de conversion du client
df['Year_Customer'] = pd.DatetimeIndex(df['Dt_Customer']).year

# Montant dépensé 
Mnt_cols= [col for col in df.columns if "Mnt" in col]
df['TotalMnt']= df[Mnt_cols].sum(axis=1)

# Total Achats
purchases_cols = [col for col in df.columns if 'Purchases' in col]
df['TotalPurchases'] = df[purchases_cols].sum(axis=1)

# Total compagnes acceptées par client
campaigns_cols = [col for col in df.columns if 'Cmp' in col] 
df['TotalCampaignsAcc'] = df[campaigns_cols].sum(axis=1)

# Voir les nouveaux attributs, par ID
df[['ID', 'Enfants', 'Year_Customer', 'TotalMnt', 'TotalPurchases', 'TotalCampaignsAcc']].head()
# Out:
#    ID  Enfants  Year_Customer  TotalMnt  TotalPurchases  TotalCampaignsAcc
# 0   0        0           2013      1198              17                  0
# 1   1        0           2014       577              18                  1
# 2   9        2           2012       120              11                  0
# 3  13        1           2013        32               6                  0
# 4  17        1           2013      1028              28                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2237 non-null   int64
#  1   Year_Birth           2237 non-null   int64
#  2   Education            2237 non-null   object
#  3   Marital_Status       2237 non-null   object
#  4   Income               2213 non-null   float64
#  5   Kidhome              2237 non-null   int64
#  6   Teenhome             2237 non-null   int64
#  7   Dt_Customer          2237 non-null   datetime64[ns]
#  8   Recency              2237 non-null   int64
#  9   MntWines             2237 non-null   int64
#  10  MntFruits            2237 non-null   int64
#  11  MntMeatProducts      2237 non-null   int64
#  12  MntFishProducts      2237 non-null   int64
#  13  MntSweetProducts     2237 non-null   int64
#  14  MntGoldProds         2237 non-null   int64
#  15  NumDealsPurchases    2237 non-null   int64
#  16  NumWebPurchases      2237 non-null   int64
#  17  NumCatalogPurchases  2237 non-null   int64
#  18  NumStorePurchases    2237 non-null   int64
#  19  NumWebVisitsMonth    2237 non-null   int64
#  20  AcceptedCmp3         2237 non-null   bool
#  21  AcceptedCmp4         2237 non-null   bool
#  22  AcceptedCmp5         2237 non-null   bool
#  23  AcceptedCmp1         2237 non-null   bool
#  24  AcceptedCmp2         2237 non-null   bool
#  25  Response             2237 non-null   bool
#  26  Complain             2237 non-null   bool
#  27  Country              2237 non-null   object
#  28  Enfants              2237 non-null   int64
#  29  Year_Customer        2237 non-null   int32
#  30  TotalMnt             2237 non-null   int64
#  31  TotalPurchases       2237 non-null   int64
#  32  TotalCampaignsAcc    2237 non-null   int64
# dtypes: bool(7), datetime64[ns](1), float64(1), int32(1), int64(20), object(3)
# memory usage: 461.1+ KB

# %% [markdown]
# Calcul de la matrice de corrélation

# %%
#Calcul de la matrice de coorélation en utilisant le test de corrélation non paramétrique (Kendall), car certaines caractéristiques sont binaires
corrs = df.drop(columns='ID').select_dtypes(include=np.number).corr(method = 'kendall')

# Heatmap des corrélations
sns.clustermap(corrs, cbar_pos=(-0.05, 0.8, 0.05, 0.18), cmap='coolwarm', center=0)
# %time
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# Illustration montrant l'effet 'Income'sur les Montants dépensés

# %%
sns.lmplot(x='Income', y='TotalMnt', data=df[df['Income']<200000])
#Nb: J'ai limité les salaires à > 200000 pour enlever les outliers

# %% [markdown]
# #Illustration qui démontre l'effet negatif d'avoir les enfants sur les dépenses:

# %%
plt.figure(figsize=(4,4))
sns.boxplot(x='Enfants', y='TotalMnt', data=df)
# Out:
# <Axes: xlabel='Enfants', ylabel='TotalMnt'>

# %% [markdown]
# Illustration qui démontre l'effet positif effect positif d'avoir des enfants sur les offres achetées:

# %%
plt.figure(figsize=(4,4))
sns.boxplot(x='Enfants', y='NumDealsPurchases', data=df);

# %% [markdown]
# Illustration qui montre l'effet positif de l'income sur le total des compagnes

# %%
plt.figure(figsize=(5.5,4))
sns.boxplot(x='TotalCampaignsAcc', y='Income', data=df[df['Income']<200000]);

# %% [markdown]
# Illustration qui montre l'effet négatif des enfants sur le nombre total des compagnes

# %%
plt.figure(figsize=(5.5,4))
sns.boxplot(x='TotalCampaignsAcc', y='Enfants', data=df);

# %% [markdown]
# Illustration linéaire du nombre de visite du mois dernier avec le nombre d'achats sur le site web:

# %%
sns.lmplot(x='NumWebVisitsMonth', y='NumWebPurchases', data=df);

# %% [markdown]
# Illustration linéarie pour voir le nombre d'offres achetés vs le nombre de visites du dernier mois

# %%
sns.lmplot(x='NumWebVisitsMonth', y='NumDealsPurchases', data=df);
